# %% [markdown]
# Wordle is a popular word guessing game. Here are the rules of the game:
#
# The game begins with a randomly selected five-letter word. The player must guess the word within ten attempts.
#
# After each guess, the player will receive feedback in the form of a list of integers of length 5, containing either 0,1, or 2 (eg [0,0,1,2,1] or [1,1,2,0,1])
#
# If the ith integer is:
#
# 0, then the ith letter of the guess is not present in the word
# 1, then the ith letter of the guess is correctly positioned
# 2, then the ith letter of the guess is present in the word but is misplaced.
# The player can use this feedback to refine their guesses and work towards solving the word. The game ends when the player correctly guesses the word or uses up all ten attempts.
# The game runs the algorithm for 10 different words and prints out your guesses and whether you got the correct answer.

# %%
import random
import requests

# %%
class Wordle:
    def __init__(self):
        self.words = []
        response = requests.get('https://raw.githubusercontent.com/charlesreid1/five-letter-words/master/sgb-words.txt')
        data = response.text
        lines = data.split('\n')
        for line in lines:
            self.words.append(line)     

        self.WORD = random.choice(self.words)   
        self.guesses = []
        self.feedbacks = [] 

    def feedback(self, guessword):
        feedback = []
        for i,letter in enumerate(guessword):
            if letter not in self.WORD:
                feedback.append(0)
            else:
                if letter == self.WORD[i]:
                    feedback.append(1)
                else:
                    feedback.append(2)
        
        return feedback
    
    def generate_guess(self, feedback = None):
        raise NotImplementedError("Implement the generate_guess() function first.")
        return ""

    def run(self):
        feedback = None
        flag = False
        for i in range(10):
            guessword = self.generate_guess(feedback)
            feedback = self.feedback(guessword)
            self.feedbacks.append(feedback)
            self.guesses.append(guessword)

            print("\tGuess #", i+1, "\t:", guessword, "\tFeedback: ", feedback)

            if guessword == self.WORD:
                flag = True
                print("\t\nSuccess.\tCorrect word: ",guessword, "\tNumber of guesses: ", len(self.feedbacks))
                break
        
        if not flag:
            print("\tFailed to find correct word within 10 guesses. \t Correct word: ", self.WORD)
        
        print('\n')

# %%
class Game:
    def __init__(self, Solver, N=5):
        self.Solver = Solver
        self.N = N
    
    def run(self):
        print("Simulating for ", self.N, " words.\n")
        for i in range(self.N):
            solver = self.Solver()
            print("WORD #[", i+1, "/", self.N, "]")
            solver.run()

# %%
class Solver(Wordle):
    def __init__(self):
        super().__init__()
        global guess
        guess = "india"

    def generate_guess(self, feedback=None):
        global guess

        feedback = Wordle.feedback(self, guess)

        def filterList(lst):
          x = 20
          while(x>0):
            for ele in lst:
             if len(ele) != 5:
               self.words.remove(ele)
            x -= 1

        #grey => 0
        #green => 1
        #orange => 2
        grey = []

        orange= []

        green = []

        #seperates the grey, orange and green alphabets. The green and orange are an array of tuple, in order to store their index
        count = 0
        for i in feedback:
            if i == 0:
                grey.append(guess[count])
            elif i == 1:
                list(guess)[count] = green.append(tuple((guess[count], count)))
            elif i == 2:
                list(guess)[count] = orange.append(tuple((guess[count], count)))
            count += 1

        wordIndex = 0
        for word in self.words:
          for letter in grey:
            if letter in word:
              self.words[wordIndex] = "0"
              break
          if len(word) == 5:
            if len(orange) != 0:
              for sub in orange:
                letter = sub[0]
                index = sub[1]
                if letter not in word:
                  self.words[wordIndex] = "0"
                  break
                if letter == word[index]:
                  self.words[wordIndex] = "0"
                  break
            if len(green) != 0:
              for sub in green:
                letter = sub[0]
                index = sub[1]
                if letter not in word:
                  self.words[wordIndex] = "0"
                  break
                if letter != word[index]:
                  self.words[wordIndex] = "0"
                  break
          wordIndex += 1

        filterList(self.words)

        guess = random.choice(self.words)
        self.words.remove(guess)

        return guess

# %%
game = Game(Solver, N=500)
game.run()
# Out:
# Simulating for  500  words.
#
# WORD #[ 1 / 500 ]
# 	Guess # 1 	: rebut 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 2 	: sully 	Feedback:  [0, 2, 2, 2, 1]
# 	Guess # 3 	: klugy 	Feedback:  [2, 1, 1, 0, 1]
# 	Guess # 4 	: fluky 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fluky 	Number of guesses:  4
#
#
# WORD #[ 2 / 500 ]
# 	Guess # 1 	: names 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 2 	: chant 	Feedback:  [0, 0, 1, 1, 0]
# 	Guess # 3 	: plank 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: flank 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  flank 	Number of guesses:  4
#
#
# WORD #[ 3 / 500 ]
# 	Guess # 1 	: saver 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: mambo 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 3 	: wacky 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 4 	: tatty 	Feedback:  [2, 1, 1, 2, 1]
# 	Guess # 5 	: fatly 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fatly 	Number of guesses:  5
#
#
# WORD #[ 4 / 500 ]
# 	Guess # 1 	: keyed 	Feedback:  [0, 2, 0, 1, 1]
# 	Guess # 2 	: hosed 	Feedback:  [0, 0, 0, 1, 1]
# 	Guess # 3 	: trued 	Feedback:  [0, 0, 0, 1, 1]
# 	Guess # 4 	: ebbed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ebbed 	Number of guesses:  4
#
#
# WORD #[ 5 / 500 ]
# 	Guess # 1 	: lames 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 2 	: arras 	Feedback:  [2, 1, 2, 2, 1]
# 	Guess # 3 	: traps 	Feedback:  [2, 1, 1, 2, 1]
# 	Guess # 4 	: prats 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  prats 	Number of guesses:  4
#
#
# WORD #[ 6 / 500 ]
# 	Guess # 1 	: kiwis 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 2 	: refix 	Feedback:  [0, 0, 0, 1, 0]
# 	Guess # 3 	: goyim 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 4 	: quoit 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  quoit 	Number of guesses:  4
#
#
# WORD #[ 7 / 500 ]
# 	Guess # 1 	: upend 	Feedback:  [0, 0, 2, 2, 1]
# 	Guess # 2 	: zoned 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 3 	: noted 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  noted 	Number of guesses:  3
#
#
# WORD #[ 8 / 500 ]
# 	Guess # 1 	: mogul 	Feedback:  [0, 0, 0, 1, 2]
# 	Guess # 2 	: lulus 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  lulus 	Number of guesses:  2
#
#
# WORD #[ 9 / 500 ]
# 	Guess # 1 	: ghost 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: belch 	Feedback:  [0, 2, 0, 0, 2]
# 	Guess # 3 	: hyper 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  hyper 	Number of guesses:  3
#
#
# WORD #[ 10 / 500 ]
# 	Guess # 1 	: giddy 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 2 	: bided 	Feedback:  [0, 1, 1, 1, 2]
# 	Guess # 3 	: video 	Feedback:  [0, 1, 1, 1, 0]
# 	Guess # 4 	: wider 	Feedback:  [0, 1, 1, 1, 2]
# 	Guess # 5 	: rides 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  rides 	Number of guesses:  5
#
#
# WORD #[ 11 / 500 ]
# 	Guess # 1 	: modes 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 2 	: pudgy 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 3 	: kudzu 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  kudzu 	Number of guesses:  3
#
#
# WORD #[ 12 / 500 ]
# 	Guess # 1 	: tense 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: nymph 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 3 	: clunk 	Feedback:  [0, 0, 1, 1, 0]
# 	Guess # 4 	: wrung 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: brung 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  brung 	Number of guesses:  5
#
#
# WORD #[ 13 / 500 ]
# 	Guess # 1 	: wills 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 2 	: filet 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 3 	: bilge 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  bilge 	Number of guesses:  3
#
#
# WORD #[ 14 / 500 ]
# 	Guess # 1 	: spivs 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 2 	: quire 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 3 	: thick 	Feedback:  [1, 0, 1, 0, 0]
# 	Guess # 4 	: twill 	Feedback:  [1, 1, 1, 0, 0]
# 	Guess # 5 	: twixt 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  twixt 	Number of guesses:  5
#
#
# WORD #[ 15 / 500 ]
# 	Guess # 1 	: spine 	Feedback:  [1, 0, 2, 2, 0]
# 	Guess # 2 	: sinks 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 3 	: sings 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: sinus 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sinus 	Number of guesses:  4
#
#
# WORD #[ 16 / 500 ]
# 	Guess # 1 	: midis 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  midis 	Number of guesses:  1
#
#
# WORD #[ 17 / 500 ]
# 	Guess # 1 	: dewey 	Feedback:  [1, 0, 0, 0, 0]
# 	Guess # 2 	: duffs 	Feedback:  [1, 2, 0, 0, 1]
# 	Guess # 3 	: drugs 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: drums 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: drubs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  drubs 	Number of guesses:  5
#
#
# WORD #[ 18 / 500 ]
# 	Guess # 1 	: geeks 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: chose 	Feedback:  [0, 0, 2, 1, 1]
# 	Guess # 3 	: fosse 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fosse 	Number of guesses:  3
#
#
# WORD #[ 19 / 500 ]
# 	Guess # 1 	: smart 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: value 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 3 	: local 	Feedback:  [2, 2, 0, 1, 1]
# 	Guess # 4 	: offal 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  offal 	Number of guesses:  4
#
#
# WORD #[ 20 / 500 ]
# 	Guess # 1 	: obits 	Feedback:  [0, 0, 2, 2, 1]
# 	Guess # 2 	: tires 	Feedback:  [2, 1, 0, 0, 1]
# 	Guess # 3 	: withs 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: situs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  situs 	Number of guesses:  4
#
#
# WORD #[ 21 / 500 ]
# 	Guess # 1 	: plays 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: break 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 3 	: facer 	Feedback:  [0, 1, 0, 1, 2]
# 	Guess # 4 	: harem 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  harem 	Number of guesses:  4
#
#
# WORD #[ 22 / 500 ]
# 	Guess # 1 	: sonar 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: plank 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 3 	: vaunt 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: haunt 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  haunt 	Number of guesses:  4
#
#
# WORD #[ 23 / 500 ]
# 	Guess # 1 	: magic 	Feedback:  [0, 1, 0, 1, 0]
# 	Guess # 2 	: basis 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 3 	: tapis 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: lapis 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  lapis 	Number of guesses:  4
#
#
# WORD #[ 24 / 500 ]
# 	Guess # 1 	: cruel 	Feedback:  [0, 1, 2, 1, 0]
# 	Guess # 2 	: urges 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  urges 	Number of guesses:  2
#
#
# WORD #[ 25 / 500 ]
# 	Guess # 1 	: wetly 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: spore 	Feedback:  [0, 0, 2, 0, 1]
# 	Guess # 3 	: vogue 	Feedback:  [0, 1, 2, 2, 1]
# 	Guess # 4 	: gouge 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gouge 	Number of guesses:  4
#
#
# WORD #[ 26 / 500 ]
# 	Guess # 1 	: wimpy 	Feedback:  [0, 1, 0, 2, 0]
# 	Guess # 2 	: pipes 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 3 	: pipet 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pipet 	Number of guesses:  3
#
#
# WORD #[ 27 / 500 ]
# 	Guess # 1 	: skull 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: photo 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 3 	: ocher 	Feedback:  [2, 0, 2, 1, 0]
# 	Guess # 4 	: homey 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  homey 	Number of guesses:  4
#
#
# WORD #[ 28 / 500 ]
# 	Guess # 1 	: owlet 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 2 	: comfy 	Feedback:  [0, 1, 0, 1, 0]
# 	Guess # 3 	: roofs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  roofs 	Number of guesses:  3
#
#
# WORD #[ 29 / 500 ]
# 	Guess # 1 	: maned 	Feedback:  [2, 2, 2, 2, 1]
# 	Guess # 2 	: amend 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  amend 	Number of guesses:  2
#
#
# WORD #[ 30 / 500 ]
# 	Guess # 1 	: slugs 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 2 	: gully 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gully 	Number of guesses:  2
#
#
# WORD #[ 31 / 500 ]
# 	Guess # 1 	: ftped 	Feedback:  [0, 0, 2, 0, 2]
# 	Guess # 2 	: droop 	Feedback:  [1, 0, 0, 0, 2]
# 	Guess # 3 	: dumps 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 4 	: dumpy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dumpy 	Number of guesses:  4
#
#
# WORD #[ 32 / 500 ]
# 	Guess # 1 	: alums 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 2 	: fatty 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 3 	: farce 	Feedback:  [1, 1, 2, 0, 2]
# 	Guess # 4 	: faker 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  faker 	Number of guesses:  4
#
#
# WORD #[ 33 / 500 ]
# 	Guess # 1 	: finds 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 2 	: mined 	Feedback:  [0, 1, 1, 0, 2]
# 	Guess # 3 	: dingy 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 4 	: dingo 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dingo 	Number of guesses:  4
#
#
# WORD #[ 34 / 500 ]
# 	Guess # 1 	: doers 	Feedback:  [1, 1, 2, 0, 0]
# 	Guess # 2 	: dovey 	Feedback:  [1, 1, 0, 1, 0]
# 	Guess # 3 	: doped 	Feedback:  [1, 1, 0, 1, 2]
# 	Guess # 4 	: dowel 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dowel 	Number of guesses:  4
#
#
# WORD #[ 35 / 500 ]
# 	Guess # 1 	: chomp 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: jolts 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 3 	: ouzel 	Feedback:  [1, 2, 0, 2, 2]
# 	Guess # 4 	: ovule 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ovule 	Number of guesses:  4
#
#
# WORD #[ 36 / 500 ]
# 	Guess # 1 	: yummy 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: pores 	Feedback:  [0, 0, 2, 1, 2]
# 	Guess # 3 	: ester 	Feedback:  [2, 2, 2, 1, 1]
# 	Guess # 4 	: steer 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  steer 	Number of guesses:  4
#
#
# WORD #[ 37 / 500 ]
# 	Guess # 1 	: occur 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 2 	: fulls 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 3 	: smuts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  smuts 	Number of guesses:  3
#
#
# WORD #[ 38 / 500 ]
# 	Guess # 1 	: tench 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: hymen 	Feedback:  [2, 0, 0, 2, 2]
# 	Guess # 3 	: whens 	Feedback:  [0, 1, 2, 1, 2]
# 	Guess # 4 	: shone 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  shone 	Number of guesses:  4
#
#
# WORD #[ 39 / 500 ]
# 	Guess # 1 	: pulps 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: evoke 	Feedback:  [1, 0, 0, 0, 2]
# 	Guess # 3 	: emery 	Feedback:  [1, 0, 1, 0, 0]
# 	Guess # 4 	: etext 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  etext 	Number of guesses:  4
#
#
# WORD #[ 40 / 500 ]
# 	Guess # 1 	: dilly 	Feedback:  [1, 2, 2, 1, 1]
# 	Guess # 2 	: drily 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 3 	: doily 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  doily 	Number of guesses:  3
#
#
# WORD #[ 41 / 500 ]
# 	Guess # 1 	: hymen 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: skunk 	Feedback:  [2, 0, 0, 2, 0]
# 	Guess # 3 	: fonts 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: gongs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gongs 	Number of guesses:  4
#
#
# WORD #[ 42 / 500 ]
# 	Guess # 1 	: smell 	Feedback:  [2, 0, 1, 2, 2]
# 	Guess # 2 	: clews 	Feedback:  [0, 2, 1, 0, 1]
# 	Guess # 3 	: leers 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: leeks 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  leeks 	Number of guesses:  4
#
#
# WORD #[ 43 / 500 ]
# 	Guess # 1 	: ousts 	Feedback:  [2, 0, 2, 0, 2]
# 	Guess # 2 	: shook 	Feedback:  [1, 0, 1, 1, 0]
# 	Guess # 3 	: spoof 	Feedback:  [1, 2, 1, 1, 0]
# 	Guess # 4 	: swoop 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: scoop 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 6 	: sloop 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sloop 	Number of guesses:  6
#
#
# WORD #[ 44 / 500 ]
# 	Guess # 1 	: mince 	Feedback:  [2, 1, 2, 0, 0]
# 	Guess # 2 	: limns 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  limns 	Number of guesses:  2
#
#
# WORD #[ 45 / 500 ]
# 	Guess # 1 	: hempy 	Feedback:  [0, 0, 0, 0, 1]
# 	Guess # 2 	: kooky 	Feedback:  [0, 0, 0, 0, 1]
# 	Guess # 3 	: furry 	Feedback:  [0, 0, 0, 0, 1]
# 	Guess # 4 	: slyly 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  slyly 	Number of guesses:  4
#
#
# WORD #[ 46 / 500 ]
# 	Guess # 1 	: feued 	Feedback:  [0, 2, 2, 1, 1]
# 	Guess # 2 	: cured 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 3 	: luted 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 4 	: tubed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tubed 	Number of guesses:  4
#
#
# WORD #[ 47 / 500 ]
# 	Guess # 1 	: pills 	Feedback:  [0, 1, 1, 2, 1]
# 	Guess # 2 	: kilts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: hilts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: silts 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 5 	: gilts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: tilts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tilts 	Number of guesses:  6
#
#
# WORD #[ 48 / 500 ]
# 	Guess # 1 	: quirk 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: fizzy 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 3 	: bitch 	Feedback:  [2, 1, 0, 0, 0]
# 	Guess # 4 	: limbs 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 5 	: limbo 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  limbo 	Number of guesses:  5
#
#
# WORD #[ 49 / 500 ]
# 	Guess # 1 	: conch 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 2 	: outen 	Feedback:  [2, 0, 2, 0, 2]
# 	Guess # 3 	: front 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  front 	Number of guesses:  3
#
#
# WORD #[ 50 / 500 ]
# 	Guess # 1 	: fucks 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 2 	: lulus 	Feedback:  [0, 1, 0, 2, 1]
# 	Guess # 3 	: rumps 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 4 	: butts 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 5 	: gusts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: ousts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ousts 	Number of guesses:  6
#
#
# WORD #[ 51 / 500 ]
# 	Guess # 1 	: robed 	Feedback:  [0, 0, 0, 2, 2]
# 	Guess # 2 	: melds 	Feedback:  [0, 1, 0, 2, 1]
# 	Guess # 3 	: decks 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 4 	: deeps 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  deeps 	Number of guesses:  4
#
#
# WORD #[ 52 / 500 ]
# 	Guess # 1 	: syrup 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: whorl 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 3 	: metro 	Feedback:  [2, 2, 0, 1, 2]
# 	Guess # 4 	: ombre 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ombre 	Number of guesses:  4
#
#
# WORD #[ 53 / 500 ]
# 	Guess # 1 	: croon 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: nulls 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 3 	: numbs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  numbs 	Number of guesses:  3
#
#
# WORD #[ 54 / 500 ]
# 	Guess # 1 	: weave 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: caper 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 3 	: pleas 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pleas 	Number of guesses:  3
#
#
# WORD #[ 55 / 500 ]
# 	Guess # 1 	: deism 	Feedback:  [1, 0, 2, 2, 0]
# 	Guess # 2 	: dicks 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 3 	: dirts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dirts 	Number of guesses:  3
#
#
# WORD #[ 56 / 500 ]
# 	Guess # 1 	: trees 	Feedback:  [0, 0, 2, 1, 1]
# 	Guess # 2 	: cokes 	Feedback:  [0, 0, 0, 1, 1]
# 	Guess # 3 	: yules 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: pubes 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 5 	: muxes 	Feedback:  [2, 1, 0, 1, 1]
# 	Guess # 6 	: fumes 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fumes 	Number of guesses:  6
#
#
# WORD #[ 57 / 500 ]
# 	Guess # 1 	: bacon 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 2 	: maven 	Feedback:  [0, 1, 0, 2, 1]
# 	Guess # 3 	: paean 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  paean 	Number of guesses:  3
#
#
# WORD #[ 58 / 500 ]
# 	Guess # 1 	: loams 	Feedback:  [0, 0, 1, 0, 2]
# 	Guess # 2 	: ukase 	Feedback:  [0, 0, 1, 2, 1]
# 	Guess # 3 	: scare 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: sware 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: stare 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 6 	: spare 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 7 	: share 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  share 	Number of guesses:  7
#
#
# WORD #[ 59 / 500 ]
# 	Guess # 1 	: whish 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: licks 	Feedback:  [2, 1, 0, 0, 1]
# 	Guess # 3 	: viols 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: pills 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: fills 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: rills 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 7 	: tills 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 8 	: sills 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 9 	: mills 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 10 	: gills 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gills 	Number of guesses:  10
#
#
# WORD #[ 60 / 500 ]
# 	Guess # 1 	: curdy 	Feedback:  [0, 2, 0, 2, 0]
# 	Guess # 2 	: umped 	Feedback:  [2, 0, 2, 2, 1]
# 	Guess # 3 	: pseud 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pseud 	Number of guesses:  3
#
#
# WORD #[ 61 / 500 ]
# 	Guess # 1 	: hicks 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: flirt 	Feedback:  [0, 2, 1, 0, 1]
# 	Guess # 3 	: built 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: guilt 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  guilt 	Number of guesses:  4
#
#
# WORD #[ 62 / 500 ]
# 	Guess # 1 	: proem 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 2 	: stele 	Feedback:  [2, 2, 1, 0, 2]
# 	Guess # 3 	: weest 	Feedback:  [0, 2, 1, 1, 1]
# 	Guess # 4 	: chest 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 5 	: guest 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  guest 	Number of guesses:  5
#
#
# WORD #[ 63 / 500 ]
# 	Guess # 1 	: bimbo 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: hippy 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 3 	: filet 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  filet 	Number of guesses:  3
#
#
# WORD #[ 64 / 500 ]
# 	Guess # 1 	: shame 	Feedback:  [0, 0, 1, 1, 2]
# 	Guess # 2 	: beamy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  beamy 	Number of guesses:  2
#
#
# WORD #[ 65 / 500 ]
# 	Guess # 1 	: bolls 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: cuppy 	Feedback:  [0, 2, 1, 2, 1]
# 	Guess # 3 	: umpty 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  umpty 	Number of guesses:  3
#
#
# WORD #[ 66 / 500 ]
# 	Guess # 1 	: studs 	Feedback:  [2, 0, 2, 2, 2]
# 	Guess # 2 	: pseud 	Feedback:  [0, 2, 2, 2, 2]
# 	Guess # 3 	: dulse 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dulse 	Number of guesses:  3
#
#
# WORD #[ 67 / 500 ]
# 	Guess # 1 	: laity 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: waive 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  waive 	Number of guesses:  2
#
#
# WORD #[ 68 / 500 ]
# 	Guess # 1 	: toddy 	Feedback:  [0, 0, 1, 2, 0]
# 	Guess # 2 	: fudge 	Feedback:  [0, 2, 1, 0, 2]
# 	Guess # 3 	: redux 	Feedback:  [0, 1, 1, 1, 0]
# 	Guess # 4 	: sedum 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sedum 	Number of guesses:  4
#
#
# WORD #[ 69 / 500 ]
# 	Guess # 1 	: sawed 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 2 	: faked 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 3 	: mazed 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: paled 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 5 	: rayed 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 6 	: raved 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 7 	: raced 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 8 	: rated 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 9 	: raged 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  raged 	Number of guesses:  9
#
#
# WORD #[ 70 / 500 ]
# 	Guess # 1 	: wench 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 2 	: conch 	Feedback:  [2, 0, 1, 1, 1]
# 	Guess # 3 	: munch 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: bunch 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: punch 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: hunch 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 7 	: lunch 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  lunch 	Number of guesses:  7
#
#
# WORD #[ 71 / 500 ]
# 	Guess # 1 	: fades 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: daddy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  daddy 	Number of guesses:  2
#
#
# WORD #[ 72 / 500 ]
# 	Guess # 1 	: saute 	Feedback:  [2, 2, 2, 2, 0]
# 	Guess # 2 	: tubas 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 3 	: tufas 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tufas 	Number of guesses:  3
#
#
# WORD #[ 73 / 500 ]
# 	Guess # 1 	: arias 	Feedback:  [2, 0, 2, 2, 2]
# 	Guess # 2 	: bassi 	Feedback:  [0, 2, 2, 1, 1]
# 	Guess # 3 	: quasi 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  quasi 	Number of guesses:  3
#
#
# WORD #[ 74 / 500 ]
# 	Guess # 1 	: shove 	Feedback:  [2, 0, 2, 0, 0]
# 	Guess # 2 	: routs 	Feedback:  [2, 1, 0, 2, 2]
# 	Guess # 3 	: worst 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  worst 	Number of guesses:  3
#
#
# WORD #[ 75 / 500 ]
# 	Guess # 1 	: peels 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: moose 	Feedback:  [0, 1, 2, 2, 2]
# 	Guess # 3 	: sower 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: sorer 	Feedback:  [1, 1, 2, 1, 1]
# 	Guess # 5 	: sober 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sober 	Number of guesses:  5
#
#
# WORD #[ 76 / 500 ]
# 	Guess # 1 	: crown 	Feedback:  [0, 2, 0, 0, 2]
# 	Guess # 2 	: ferny 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 3 	: runes 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  runes 	Number of guesses:  3
#
#
# WORD #[ 77 / 500 ]
# 	Guess # 1 	: metal 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 2 	: straw 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 3 	: strap 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 4 	: stray 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  stray 	Number of guesses:  4
#
#
# WORD #[ 78 / 500 ]
# 	Guess # 1 	: mooed 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 2 	: joyed 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 3 	: doted 	Feedback:  [2, 1, 0, 1, 1]
# 	Guess # 4 	: poxed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: coxed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: boxed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 7 	: foxed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  foxed 	Number of guesses:  7
#
#
# WORD #[ 79 / 500 ]
# 	Guess # 1 	: feeds 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 2 	: doter 	Feedback:  [1, 0, 0, 2, 0]
# 	Guess # 3 	: duple 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  duple 	Number of guesses:  3
#
#
# WORD #[ 80 / 500 ]
# 	Guess # 1 	: umbel 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 2 	: tress 	Feedback:  [0, 0, 1, 2, 1]
# 	Guess # 3 	: seeks 	Feedback:  [2, 1, 1, 2, 1]
# 	Guess # 4 	: keeps 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  keeps 	Number of guesses:  4
#
#
# WORD #[ 81 / 500 ]
# 	Guess # 1 	: hyper 	Feedback:  [0, 0, 0, 2, 2]
# 	Guess # 2 	: seers 	Feedback:  [0, 1, 2, 2, 0]
# 	Guess # 3 	: verge 	Feedback:  [2, 1, 2, 0, 1]
# 	Guess # 4 	: revue 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  revue 	Number of guesses:  4
#
#
# WORD #[ 82 / 500 ]
# 	Guess # 1 	: liken 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: brink 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 3 	: chink 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 4 	: stink 	Feedback:  [0, 2, 1, 1, 1]
# 	Guess # 5 	: twink 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  twink 	Number of guesses:  5
#
#
# WORD #[ 83 / 500 ]
# 	Guess # 1 	: godly 	Feedback:  [0, 2, 1, 2, 0]
# 	Guess # 2 	: older 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  older 	Number of guesses:  2
#
#
# WORD #[ 84 / 500 ]
# 	Guess # 1 	: strep 	Feedback:  [0, 2, 0, 0, 2]
# 	Guess # 2 	: pffft 	Feedback:  [1, 0, 0, 0, 2]
# 	Guess # 3 	: potty 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: putty 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  putty 	Number of guesses:  4
#
#
# WORD #[ 85 / 500 ]
# 	Guess # 1 	: gauss 	Feedback:  [1, 1, 0, 2, 1]
# 	Guess # 2 	: gales 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 3 	: gates 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: gages 	Feedback:  [1, 1, 2, 1, 1]
# 	Guess # 5 	: gazes 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 6 	: gapes 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 7 	: gases 	Feedback:  [1, 1, 2, 1, 1]
# 	Guess # 8 	: games 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  games 	Number of guesses:  8
#
#
# WORD #[ 86 / 500 ]
# 	Guess # 1 	: unify 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 2 	: envoi 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  envoi 	Number of guesses:  2
#
#
# WORD #[ 87 / 500 ]
# 	Guess # 1 	: girls 	Feedback:  [0, 1, 0, 2, 0]
# 	Guess # 2 	: pilot 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 3 	: filch 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: zilch 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  zilch 	Number of guesses:  4
#
#
# WORD #[ 88 / 500 ]
# 	Guess # 1 	: gawks 	Feedback:  [2, 1, 0, 0, 0]
# 	Guess # 2 	: pager 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 3 	: jaggy 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 4 	: fagot 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fagot 	Number of guesses:  4
#
#
# WORD #[ 89 / 500 ]
# 	Guess # 1 	: mists 	Feedback:  [2, 1, 2, 0, 1]
# 	Guess # 2 	: limbs 	Feedback:  [0, 1, 2, 0, 1]
# 	Guess # 3 	: firms 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  firms 	Number of guesses:  3
#
#
# WORD #[ 90 / 500 ]
# 	Guess # 1 	: picky 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 2 	: pipet 	Feedback:  [1, 1, 2, 0, 1]
# 	Guess # 3 	: pivot 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: pilot 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pilot 	Number of guesses:  4
#
#
# WORD #[ 91 / 500 ]
# 	Guess # 1 	: gaunt 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 2 	: loans 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 3 	: scans 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: spans 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: swans 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  swans 	Number of guesses:  5
#
#
# WORD #[ 92 / 500 ]
# 	Guess # 1 	: biped 	Feedback:  [0, 2, 2, 1, 1]
# 	Guess # 2 	: spied 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  spied 	Number of guesses:  2
#
#
# WORD #[ 93 / 500 ]
# 	Guess # 1 	: tarot 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: phage 	Feedback:  [0, 2, 1, 0, 2]
# 	Guess # 3 	: leash 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: beach 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  beach 	Number of guesses:  4
#
#
# WORD #[ 94 / 500 ]
# 	Guess # 1 	: natal 	Feedback:  [1, 1, 0, 2, 0]
# 	Guess # 2 	: nappy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  nappy 	Number of guesses:  2
#
#
# WORD #[ 95 / 500 ]
# 	Guess # 1 	: mired 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 2 	: dippy 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 3 	: dicut 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dicut 	Number of guesses:  3
#
#
# WORD #[ 96 / 500 ]
# 	Guess # 1 	: ghoul 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: morts 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 3 	: vower 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: poker 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: joker 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  joker 	Number of guesses:  5
#
#
# WORD #[ 97 / 500 ]
# 	Guess # 1 	: laude 	Feedback:  [2, 1, 0, 2, 0]
# 	Guess # 2 	: salad 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  salad 	Number of guesses:  2
#
#
# WORD #[ 98 / 500 ]
# 	Guess # 1 	: topic 	Feedback:  [2, 0, 0, 1, 2]
# 	Guess # 2 	: cubit 	Feedback:  [2, 0, 0, 1, 1]
# 	Guess # 3 	: licit 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  licit 	Number of guesses:  3
#
#
# WORD #[ 99 / 500 ]
# 	Guess # 1 	: offer 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: muggy 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 3 	: sulky 	Feedback:  [2, 1, 0, 1, 1]
# 	Guess # 4 	: husky 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  husky 	Number of guesses:  4
#
#
# WORD #[ 100 / 500 ]
# 	Guess # 1 	: plate 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: gaffs 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 3 	: backs 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: basks 	Feedback:  [1, 1, 2, 1, 1]
# 	Guess # 5 	: barks 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  barks 	Number of guesses:  5
#
#
# WORD #[ 101 / 500 ]
# 	Guess # 1 	: hypos 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 2 	: forte 	Feedback:  [0, 2, 2, 1, 1]
# 	Guess # 3 	: wrote 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  wrote 	Number of guesses:  3
#
#
# WORD #[ 102 / 500 ]
# 	Guess # 1 	: doter 	Feedback:  [2, 0, 0, 1, 0]
# 	Guess # 2 	: sexed 	Feedback:  [0, 2, 0, 1, 1]
# 	Guess # 3 	: egged 	Feedback:  [2, 0, 0, 1, 1]
# 	Guess # 4 	: clued 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: blued 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  blued 	Number of guesses:  5
#
#
# WORD #[ 103 / 500 ]
# 	Guess # 1 	: blown 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: tents 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 3 	: gunky 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gunky 	Number of guesses:  3
#
#
# WORD #[ 104 / 500 ]
# 	Guess # 1 	: geoid 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 2 	: droid 	Feedback:  [2, 0, 1, 1, 1]
# 	Guess # 3 	: ovoid 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ovoid 	Number of guesses:  3
#
#
# WORD #[ 105 / 500 ]
# 	Guess # 1 	: flack 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 2 	: males 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 3 	: apple 	Feedback:  [2, 0, 0, 2, 2]
# 	Guess # 4 	: wheal 	Feedback:  [0, 0, 2, 1, 1]
# 	Guess # 5 	: equal 	Feedback:  [2, 0, 0, 1, 1]
# 	Guess # 6 	: regal 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  regal 	Number of guesses:  6
#
#
# WORD #[ 106 / 500 ]
# 	Guess # 1 	: dribs 	Feedback:  [1, 0, 1, 0, 2]
# 	Guess # 2 	: deism 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 3 	: deist 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  deist 	Number of guesses:  3
#
#
# WORD #[ 107 / 500 ]
# 	Guess # 1 	: paves 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: karat 	Feedback:  [0, 1, 0, 2, 2]
# 	Guess # 3 	: malty 	Feedback:  [0, 1, 0, 2, 1]
# 	Guess # 4 	: taffy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  taffy 	Number of guesses:  4
#
#
# WORD #[ 108 / 500 ]
# 	Guess # 1 	: neato 	Feedback:  [2, 0, 1, 0, 0]
# 	Guess # 2 	: crank 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 3 	: plank 	Feedback:  [2, 0, 1, 1, 1]
# 	Guess # 4 	: spank 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  spank 	Number of guesses:  4
#
#
# WORD #[ 109 / 500 ]
# 	Guess # 1 	: mungs 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 2 	: songs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  songs 	Number of guesses:  2
#
#
# WORD #[ 110 / 500 ]
# 	Guess # 1 	: towed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 2 	: bowed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: lowed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: cowed 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: mowed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  mowed 	Number of guesses:  5
#
#
# WORD #[ 111 / 500 ]
# 	Guess # 1 	: dodge 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 2 	: lodge 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: bodge 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  bodge 	Number of guesses:  3
#
#
# WORD #[ 112 / 500 ]
# 	Guess # 1 	: snots 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: enemy 	Feedback:  [2, 1, 2, 0, 0]
# 	Guess # 3 	: uncle 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  uncle 	Number of guesses:  3
#
#
# WORD #[ 113 / 500 ]
# 	Guess # 1 	: calix 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 2 	: trait 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 3 	: aphis 	Feedback:  [1, 0, 0, 1, 1]
# 	Guess # 4 	: aegis 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  aegis 	Number of guesses:  4
#
#
# WORD #[ 114 / 500 ]
# 	Guess # 1 	: rears 	Feedback:  [1, 0, 2, 2, 1]
# 	Guess # 2 	: ramps 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 3 	: rasps 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  rasps 	Number of guesses:  3
#
#
# WORD #[ 115 / 500 ]
# 	Guess # 1 	: kapok 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 2 	: armor 	Feedback:  [1, 1, 0, 1, 2]
# 	Guess # 3 	: argot 	Feedback:  [1, 1, 0, 1, 0]
# 	Guess # 4 	: arrow 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  arrow 	Number of guesses:  4
#
#
# WORD #[ 116 / 500 ]
# 	Guess # 1 	: lames 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: mammy 	Feedback:  [1, 1, 1, 2, 0]
# 	Guess # 3 	: mambo 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  mambo 	Number of guesses:  3
#
#
# WORD #[ 117 / 500 ]
# 	Guess # 1 	: poach 	Feedback:  [0, 0, 2, 0, 2]
# 	Guess # 2 	: shear 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 3 	: hayey 	Feedback:  [1, 1, 0, 2, 0]
# 	Guess # 4 	: halve 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  halve 	Number of guesses:  4
#
#
# WORD #[ 118 / 500 ]
# 	Guess # 1 	: ruses 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 2 	: troop 	Feedback:  [2, 1, 1, 2, 0]
# 	Guess # 3 	: broth 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  broth 	Number of guesses:  3
#
#
# WORD #[ 119 / 500 ]
# 	Guess # 1 	: spoke 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: curer 	Feedback:  [0, 0, 1, 1, 2]
# 	Guess # 3 	: egret 	Feedback:  [2, 0, 1, 1, 1]
# 	Guess # 4 	: beret 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  beret 	Number of guesses:  4
#
#
# WORD #[ 120 / 500 ]
# 	Guess # 1 	: turfy 	Feedback:  [2, 2, 0, 1, 0]
# 	Guess # 2 	: stuff 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  stuff 	Number of guesses:  2
#
#
# WORD #[ 121 / 500 ]
# 	Guess # 1 	: codas 	Feedback:  [0, 0, 1, 2, 0]
# 	Guess # 2 	: added 	Feedback:  [2, 2, 1, 0, 2]
# 	Guess # 3 	: madly 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  madly 	Number of guesses:  3
#
#
# WORD #[ 122 / 500 ]
# 	Guess # 1 	: curbs 	Feedback:  [0, 1, 2, 0, 1]
# 	Guess # 2 	: ruses 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 3 	: rusts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  rusts 	Number of guesses:  3
#
#
# WORD #[ 123 / 500 ]
# 	Guess # 1 	: acrid 	Feedback:  [1, 0, 0, 1, 1]
# 	Guess # 2 	: aphid 	Feedback:  [1, 0, 0, 1, 1]
# 	Guess # 3 	: avoid 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  avoid 	Number of guesses:  3
#
#
# WORD #[ 124 / 500 ]
# 	Guess # 1 	: icily 	Feedback:  [1, 0, 1, 2, 0]
# 	Guess # 2 	: ilium 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ilium 	Number of guesses:  2
#
#
# WORD #[ 125 / 500 ]
# 	Guess # 1 	: minks 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 2 	: mints 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 3 	: mines 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  mines 	Number of guesses:  3
#
#
# WORD #[ 126 / 500 ]
# 	Guess # 1 	: lapin 	Feedback:  [0, 1, 0, 1, 2]
# 	Guess # 2 	: manic 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  manic 	Number of guesses:  2
#
#
# WORD #[ 127 / 500 ]
# 	Guess # 1 	: teach 	Feedback:  [1, 0, 1, 0, 0]
# 	Guess # 2 	: tzars 	Feedback:  [1, 0, 1, 0, 2]
# 	Guess # 3 	: toast 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  toast 	Number of guesses:  3
#
#
# WORD #[ 128 / 500 ]
# 	Guess # 1 	: hertz 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: close 	Feedback:  [0, 0, 0, 1, 2]
# 	Guess # 3 	: guess 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  guess 	Number of guesses:  3
#
#
# WORD #[ 129 / 500 ]
# 	Guess # 1 	: forky 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 2 	: grope 	Feedback:  [0, 2, 1, 0, 1]
# 	Guess # 3 	: store 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: swore 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: score 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  score 	Number of guesses:  5
#
#
# WORD #[ 130 / 500 ]
# 	Guess # 1 	: vacuo 	Feedback:  [0, 2, 0, 0, 2]
# 	Guess # 2 	: topaz 	Feedback:  [0, 1, 0, 2, 0]
# 	Guess # 3 	: foals 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: soars 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 5 	: hoars 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: roars 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 7 	: boars 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  boars 	Number of guesses:  7
#
#
# WORD #[ 131 / 500 ]
# 	Guess # 1 	: carps 	Feedback:  [1, 2, 0, 2, 2]
# 	Guess # 2 	: clasp 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  clasp 	Number of guesses:  2
#
#
# WORD #[ 132 / 500 ]
# 	Guess # 1 	: tutti 	Feedback:  [1, 0, 2, 2, 2]
# 	Guess # 2 	: trios 	Feedback:  [1, 2, 2, 0, 1]
# 	Guess # 3 	: tiers 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tiers 	Number of guesses:  3
#
#
# WORD #[ 133 / 500 ]
# 	Guess # 1 	: ember 	Feedback:  [2, 0, 0, 2, 2]
# 	Guess # 2 	: utero 	Feedback:  [0, 0, 2, 1, 2]
# 	Guess # 3 	: score 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: swore 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  swore 	Number of guesses:  4
#
#
# WORD #[ 134 / 500 ]
# 	Guess # 1 	: quilt 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 2 	: birch 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 3 	: mixer 	Feedback:  [2, 1, 0, 1, 2]
# 	Guess # 4 	: rimes 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  rimes 	Number of guesses:  4
#
#
# WORD #[ 135 / 500 ]
# 	Guess # 1 	: foxes 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 2 	: locos 	Feedback:  [1, 1, 0, 2, 1]
# 	Guess # 3 	: loops 	Feedback:  [1, 1, 2, 0, 1]
# 	Guess # 4 	: lotus 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 5 	: lolls 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  lolls 	Number of guesses:  5
#
#
# WORD #[ 136 / 500 ]
# 	Guess # 1 	: axing 	Feedback:  [1, 0, 1, 2, 0]
# 	Guess # 2 	: apian 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 3 	: avian 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  avian 	Number of guesses:  3
#
#
# WORD #[ 137 / 500 ]
# 	Guess # 1 	: gruff 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: jello 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 3 	: sexes 	Feedback:  [2, 1, 0, 2, 1]
# 	Guess # 4 	: peeps 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 5 	: beeps 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: keeps 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 7 	: weeps 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 8 	: veeps 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  veeps 	Number of guesses:  8
#
#
# WORD #[ 138 / 500 ]
# 	Guess # 1 	: toady 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: dread 	Feedback:  [2, 0, 2, 2, 1]
# 	Guess # 3 	: paged 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: waked 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 5 	: baled 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 6 	: saved 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 7 	: hazed 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 8 	: maced 	Feedback:  [2, 1, 0, 1, 1]
# 	Guess # 9 	: famed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  famed 	Number of guesses:  9
#
#
# WORD #[ 139 / 500 ]
# 	Guess # 1 	: soots 	Feedback:  [2, 1, 2, 2, 1]
# 	Guess # 2 	: toffs 	Feedback:  [2, 1, 0, 0, 1]
# 	Guess # 3 	: motes 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: moths 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  moths 	Number of guesses:  4
#
#
# WORD #[ 140 / 500 ]
# 	Guess # 1 	: lamas 	Feedback:  [2, 2, 0, 2, 0]
# 	Guess # 2 	: trawl 	Feedback:  [0, 0, 2, 0, 1]
# 	Guess # 3 	: alkyl 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  alkyl 	Number of guesses:  3
#
#
# WORD #[ 141 / 500 ]
# 	Guess # 1 	: hewed 	Feedback:  [0, 2, 2, 2, 2]
# 	Guess # 2 	: dwell 	Feedback:  [2, 1, 1, 0, 0]
# 	Guess # 3 	: swede 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  swede 	Number of guesses:  3
#
#
# WORD #[ 142 / 500 ]
# 	Guess # 1 	: krona 	Feedback:  [0, 0, 0, 2, 1]
# 	Guess # 2 	: yenta 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  yenta 	Number of guesses:  2
#
#
# WORD #[ 143 / 500 ]
# 	Guess # 1 	: emote 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 2 	: huger 	Feedback:  [0, 0, 0, 2, 2]
# 	Guess # 3 	: clerk 	Feedback:  [0, 0, 2, 2, 2]
# 	Guess # 4 	: perky 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: jerky 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  jerky 	Number of guesses:  5
#
#
# WORD #[ 144 / 500 ]
# 	Guess # 1 	: carom 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: flaps 	Feedback:  [0, 0, 1, 0, 2]
# 	Guess # 3 	: shaky 	Feedback:  [1, 1, 1, 0, 0]
# 	Guess # 4 	: shave 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  shave 	Number of guesses:  4
#
#
# WORD #[ 145 / 500 ]
# 	Guess # 1 	: soles 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 2 	: floor 	Feedback:  [1, 1, 1, 2, 1]
# 	Guess # 3 	: flour 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  flour 	Number of guesses:  3
#
#
# WORD #[ 146 / 500 ]
# 	Guess # 1 	: squat 	Feedback:  [2, 0, 0, 1, 0]
# 	Guess # 2 	: orcas 	Feedback:  [2, 0, 2, 1, 1]
# 	Guess # 3 	: comas 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  comas 	Number of guesses:  3
#
#
# WORD #[ 147 / 500 ]
# 	Guess # 1 	: brine 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: winos 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 3 	: hints 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: tints 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 5 	: pints 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: lints 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 7 	: mints 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  mints 	Number of guesses:  7
#
#
# WORD #[ 148 / 500 ]
# 	Guess # 1 	: ruing 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 2 	: fling 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fling 	Number of guesses:  2
#
#
# WORD #[ 149 / 500 ]
# 	Guess # 1 	: tamer 	Feedback:  [1, 2, 0, 2, 2]
# 	Guess # 2 	: trace 	Feedback:  [1, 1, 2, 0, 2]
# 	Guess # 3 	: treat 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  treat 	Number of guesses:  3
#
#
# WORD #[ 150 / 500 ]
# 	Guess # 1 	: sicks 	Feedback:  [1, 1, 0, 0, 2]
# 	Guess # 2 	: sirup 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sirup 	Number of guesses:  2
#
#
# WORD #[ 151 / 500 ]
# 	Guess # 1 	: jakes 	Feedback:  [0, 2, 0, 2, 2]
# 	Guess # 2 	: scale 	Feedback:  [1, 2, 1, 0, 1]
# 	Guess # 3 	: space 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  space 	Number of guesses:  3
#
#
# WORD #[ 152 / 500 ]
# 	Guess # 1 	: emote 	Feedback:  [2, 0, 0, 0, 2]
# 	Guess # 2 	: perks 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 3 	: fuels 	Feedback:  [0, 2, 2, 2, 1]
# 	Guess # 4 	: slues 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  slues 	Number of guesses:  4
#
#
# WORD #[ 153 / 500 ]
# 	Guess # 1 	: girds 	Feedback:  [0, 2, 2, 2, 0]
# 	Guess # 2 	: drily 	Feedback:  [2, 1, 1, 0, 0]
# 	Guess # 3 	: pried 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: cried 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: tried 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tried 	Number of guesses:  5
#
#
# WORD #[ 154 / 500 ]
# 	Guess # 1 	: ghoul 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: bhoys 	Feedback:  [0, 1, 1, 0, 2]
# 	Guess # 3 	: shove 	Feedback:  [2, 1, 1, 0, 1]
# 	Guess # 4 	: chose 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  chose 	Number of guesses:  4
#
#
# WORD #[ 155 / 500 ]
# 	Guess # 1 	: fazes 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 2 	: fatal 	Feedback:  [1, 1, 2, 2, 2]
# 	Guess # 3 	: fault 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fault 	Number of guesses:  3
#
#
# WORD #[ 156 / 500 ]
# 	Guess # 1 	: vivid 	Feedback:  [0, 2, 0, 1, 2]
# 	Guess # 2 	: dogie 	Feedback:  [1, 0, 0, 1, 2]
# 	Guess # 3 	: debit 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  debit 	Number of guesses:  3
#
#
# WORD #[ 157 / 500 ]
# 	Guess # 1 	: lawny 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 2 	: moans 	Feedback:  [0, 0, 1, 1, 0]
# 	Guess # 3 	: grant 	Feedback:  [0, 0, 1, 1, 2]
# 	Guess # 4 	: thanx 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 5 	: thank 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 6 	: thane 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  thane 	Number of guesses:  6
#
#
# WORD #[ 158 / 500 ]
# 	Guess # 1 	: oinks 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 2 	: wines 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: nines 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 4 	: mines 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: pines 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: lines 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 7 	: fines 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 8 	: sines 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sines 	Number of guesses:  8
#
#
# WORD #[ 159 / 500 ]
# 	Guess # 1 	: mazed 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 2 	: darts 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 3 	: daffy 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 4 	: dally 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dally 	Number of guesses:  4
#
#
# WORD #[ 160 / 500 ]
# 	Guess # 1 	: auger 	Feedback:  [2, 0, 0, 1, 0]
# 	Guess # 2 	: bates 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 3 	: faces 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 4 	: hames 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 5 	: oases 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 6 	: lazes 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 7 	: wakes 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 8 	: jakes 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  jakes 	Number of guesses:  8
#
#
# WORD #[ 161 / 500 ]
# 	Guess # 1 	: conks 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 2 	: wonts 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 3 	: hones 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: zones 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: bones 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: nones 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 7 	: pones 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pones 	Number of guesses:  7
#
#
# WORD #[ 162 / 500 ]
# 	Guess # 1 	: wombs 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 2 	: tweet 	Feedback:  [0, 2, 1, 2, 0]
# 	Guess # 3 	: chewy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  chewy 	Number of guesses:  3
#
#
# WORD #[ 163 / 500 ]
# 	Guess # 1 	: parks 	Feedback:  [1, 1, 1, 0, 0]
# 	Guess # 2 	: parch 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  parch 	Number of guesses:  2
#
#
# WORD #[ 164 / 500 ]
# 	Guess # 1 	: fills 	Feedback:  [1, 2, 0, 0, 0]
# 	Guess # 2 	: fermi 	Feedback:  [1, 0, 2, 0, 2]
# 	Guess # 3 	: frizz 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  frizz 	Number of guesses:  3
#
#
# WORD #[ 165 / 500 ]
# 	Guess # 1 	: horsy 	Feedback:  [0, 0, 1, 2, 2]
# 	Guess # 2 	: syrup 	Feedback:  [2, 1, 1, 0, 0]
# 	Guess # 3 	: lyres 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  lyres 	Number of guesses:  3
#
#
# WORD #[ 166 / 500 ]
# 	Guess # 1 	: blobs 	Feedback:  [0, 0, 2, 0, 1]
# 	Guess # 2 	: topos 	Feedback:  [2, 1, 0, 2, 1]
# 	Guess # 3 	: morts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  morts 	Number of guesses:  3
#
#
# WORD #[ 167 / 500 ]
# 	Guess # 1 	: forgo 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 2 	: toque 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 3 	: bombe 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 4 	: loose 	Feedback:  [2, 1, 2, 2, 1]
# 	Guess # 5 	: socle 	Feedback:  [1, 1, 0, 2, 1]
# 	Guess # 6 	: solve 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  solve 	Number of guesses:  6
#
#
# WORD #[ 168 / 500 ]
# 	Guess # 1 	: calla 	Feedback:  [2, 2, 0, 0, 1]
# 	Guess # 2 	: abaca 	Feedback:  [2, 0, 2, 2, 1]
# 	Guess # 3 	: schwa 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  schwa 	Number of guesses:  3
#
#
# WORD #[ 169 / 500 ]
# 	Guess # 1 	: twist 	Feedback:  [2, 0, 1, 2, 2]
# 	Guess # 2 	: suite 	Feedback:  [2, 0, 1, 1, 0]
# 	Guess # 3 	: flits 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  flits 	Number of guesses:  3
#
#
# WORD #[ 170 / 500 ]
# 	Guess # 1 	: hatch 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 2 	: paste 	Feedback:  [0, 1, 0, 2, 0]
# 	Guess # 3 	: tarry 	Feedback:  [2, 1, 0, 0, 0]
# 	Guess # 4 	: fault 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fault 	Number of guesses:  4
#
#
# WORD #[ 171 / 500 ]
# 	Guess # 1 	: silky 	Feedback:  [2, 2, 2, 0, 0]
# 	Guess # 2 	: plies 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 3 	: olios 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: flits 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 5 	: bliss 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  bliss 	Number of guesses:  5
#
#
# WORD #[ 172 / 500 ]
# 	Guess # 1 	: bench 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 2 	: keens 	Feedback:  [0, 1, 2, 2, 1]
# 	Guess # 3 	: nexus 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 4 	: nerfs 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: nerts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  nerts 	Number of guesses:  5
#
#
# WORD #[ 173 / 500 ]
# 	Guess # 1 	: leach 	Feedback:  [0, 1, 2, 2, 0]
# 	Guess # 2 	: recap 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  recap 	Number of guesses:  2
#
#
# WORD #[ 174 / 500 ]
# 	Guess # 1 	: whelk 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 2 	: style 	Feedback:  [1, 0, 0, 1, 2]
# 	Guess # 3 	: sells 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sells 	Number of guesses:  3
#
#
# WORD #[ 175 / 500 ]
# 	Guess # 1 	: forts 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: vouch 	Feedback:  [0, 1, 2, 2, 0]
# 	Guess # 3 	: coypu 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  coypu 	Number of guesses:  3
#
#
# WORD #[ 176 / 500 ]
# 	Guess # 1 	: amber 	Feedback:  [2, 2, 0, 2, 0]
# 	Guess # 2 	: mauve 	Feedback:  [2, 2, 0, 0, 2]
# 	Guess # 3 	: gleam 	Feedback:  [0, 0, 2, 2, 2]
# 	Guess # 4 	: exams 	Feedback:  [2, 0, 1, 1, 1]
# 	Guess # 5 	: teams 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  teams 	Number of guesses:  5
#
#
# WORD #[ 177 / 500 ]
# 	Guess # 1 	: oinky 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 2 	: niche 	Feedback:  [2, 1, 0, 0, 2]
# 	Guess # 3 	: riven 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: risen 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  risen 	Number of guesses:  4
#
#
# WORD #[ 178 / 500 ]
# 	Guess # 1 	: inert 	Feedback:  [1, 1, 2, 0, 1]
# 	Guess # 2 	: inlet 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  inlet 	Number of guesses:  2
#
#
# WORD #[ 179 / 500 ]
# 	Guess # 1 	: pekoe 	Feedback:  [0, 2, 0, 0, 2]
# 	Guess # 2 	: shelf 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 3 	: erect 	Feedback:  [1, 2, 1, 0, 0]
# 	Guess # 4 	: emery 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: every 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  every 	Number of guesses:  5
#
#
# WORD #[ 180 / 500 ]
# 	Guess # 1 	: dozes 	Feedback:  [1, 0, 0, 0, 0]
# 	Guess # 2 	: duchy 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 3 	: dully 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  dully 	Number of guesses:  3
#
#
# WORD #[ 181 / 500 ]
# 	Guess # 1 	: felts 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: mussy 	Feedback:  [0, 0, 2, 2, 1]
# 	Guess # 3 	: soggy 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 4 	: soppy 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 5 	: sorry 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sorry 	Number of guesses:  5
#
#
# WORD #[ 182 / 500 ]
# 	Guess # 1 	: bombe 	Feedback:  [0, 0, 1, 0, 1]
# 	Guess # 2 	: lemme 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: femme 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  femme 	Number of guesses:  3
#
#
# WORD #[ 183 / 500 ]
# 	Guess # 1 	: tours 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: hurly 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 3 	: upper 	Feedback:  [2, 0, 0, 2, 1]
# 	Guess # 4 	: recur 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  recur 	Number of guesses:  4
#
#
# WORD #[ 184 / 500 ]
# ...
#
# Success.	Correct word:  topos 	Number of guesses:  4
#
#
# WORD #[ 274 / 500 ]
# 	Guess # 1 	: potty 	Feedback:  [1, 1, 0, 0, 0]
# 	Guess # 2 	: porch 	Feedback:  [1, 1, 1, 0, 0]
# 	Guess # 3 	: pores 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: porks 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  porks 	Number of guesses:  4
#
#
# WORD #[ 275 / 500 ]
# 	Guess # 1 	: axles 	Feedback:  [2, 0, 0, 1, 1]
# 	Guess # 2 	: safes 	Feedback:  [2, 1, 0, 1, 1]
# 	Guess # 3 	: hames 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 4 	: mares 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 5 	: mates 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 6 	: makes 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  makes 	Number of guesses:  6
#
#
# WORD #[ 276 / 500 ]
# 	Guess # 1 	: posit 	Feedback:  [1, 0, 0, 1, 1]
# 	Guess # 2 	: pewit 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  pewit 	Number of guesses:  2
#
#
# WORD #[ 277 / 500 ]
# 	Guess # 1 	: spark 	Feedback:  [0, 2, 1, 0, 0]
# 	Guess # 2 	: place 	Feedback:  [1, 0, 1, 0, 1]
# 	Guess # 3 	: phage 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  phage 	Number of guesses:  3
#
#
# WORD #[ 278 / 500 ]
# 	Guess # 1 	: conks 	Feedback:  [1, 0, 2, 2, 0]
# 	Guess # 2 	: chunk 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  chunk 	Number of guesses:  2
#
#
# WORD #[ 279 / 500 ]
# 	Guess # 1 	: lisps 	Feedback:  [2, 1, 2, 0, 1]
# 	Guess # 2 	: viols 	Feedback:  [0, 1, 0, 2, 1]
# 	Guess # 3 	: kilts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: tilts 	Feedback:  [2, 1, 1, 1, 1]
# 	Guess # 5 	: hilts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 6 	: silts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  silts 	Number of guesses:  6
#
#
# WORD #[ 280 / 500 ]
# 	Guess # 1 	: scare 	Feedback:  [0, 2, 1, 2, 1]
# 	Guess # 2 	: trace 	Feedback:  [0, 1, 1, 2, 1]
# 	Guess # 3 	: craze 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  craze 	Number of guesses:  3
#
#
# WORD #[ 281 / 500 ]
# 	Guess # 1 	: allot 	Feedback:  [2, 2, 1, 0, 0]
# 	Guess # 2 	: selah 	Feedback:  [0, 2, 1, 2, 0]
# 	Guess # 3 	: baler 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  baler 	Number of guesses:  3
#
#
# WORD #[ 282 / 500 ]
# 	Guess # 1 	: refry 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: sheet 	Feedback:  [1, 0, 2, 2, 0]
# 	Guess # 3 	: slope 	Feedback:  [1, 0, 2, 0, 1]
# 	Guess # 4 	: souse 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  souse 	Number of guesses:  4
#
#
# WORD #[ 283 / 500 ]
# 	Guess # 1 	: prosy 	Feedback:  [1, 0, 1, 2, 0]
# 	Guess # 2 	: pools 	Feedback:  [1, 2, 1, 2, 1]
# 	Guess # 3 	: plows 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: plots 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  plots 	Number of guesses:  4
#
#
# WORD #[ 284 / 500 ]
# 	Guess # 1 	: voids 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: field 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: yield 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: wield 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  wield 	Number of guesses:  4
#
#
# WORD #[ 285 / 500 ]
# 	Guess # 1 	: raspy 	Feedback:  [2, 1, 2, 0, 0]
# 	Guess # 2 	: mares 	Feedback:  [0, 1, 2, 1, 2]
# 	Guess # 3 	: saber 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 4 	: safer 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 5 	: saver 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 6 	: sager 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 7 	: sawer 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sawer 	Number of guesses:  7
#
#
# WORD #[ 286 / 500 ]
# 	Guess # 1 	: oring 	Feedback:  [0, 0, 2, 1, 0]
# 	Guess # 2 	: jinns 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  jinns 	Number of guesses:  2
#
#
# WORD #[ 287 / 500 ]
# 	Guess # 1 	: haled 	Feedback:  [0, 2, 0, 2, 2]
# 	Guess # 2 	: deads 	Feedback:  [1, 1, 1, 2, 0]
# 	Guess # 3 	: deary 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  deary 	Number of guesses:  3
#
#
# WORD #[ 288 / 500 ]
# 	Guess # 1 	: shelf 	Feedback:  [1, 0, 0, 0, 0]
# 	Guess # 2 	: scoot 	Feedback:  [1, 2, 0, 0, 2]
# 	Guess # 3 	: stuck 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  stuck 	Number of guesses:  3
#
#
# WORD #[ 289 / 500 ]
# 	Guess # 1 	: scour 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: elect 	Feedback:  [2, 0, 2, 2, 2]
# 	Guess # 3 	: techy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  techy 	Number of guesses:  3
#
#
# WORD #[ 290 / 500 ]
# 	Guess # 1 	: kraal 	Feedback:  [0, 0, 2, 1, 2]
# 	Guess # 2 	: bolas 	Feedback:  [0, 2, 2, 1, 0]
# 	Guess # 3 	: float 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  float 	Number of guesses:  3
#
#
# WORD #[ 291 / 500 ]
# 	Guess # 1 	: pasty 	Feedback:  [2, 2, 2, 0, 0]
# 	Guess # 2 	: slaps 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 3 	: soaps 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: swaps 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  swaps 	Number of guesses:  4
#
#
# WORD #[ 292 / 500 ]
# 	Guess # 1 	: giddy 	Feedback:  [0, 1, 1, 2, 0]
# 	Guess # 2 	: rides 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 3 	: width 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  width 	Number of guesses:  3
#
#
# WORD #[ 293 / 500 ]
# 	Guess # 1 	: aquas 	Feedback:  [2, 0, 0, 2, 1]
# 	Guess # 2 	: males 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 3 	: frays 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  frays 	Number of guesses:  3
#
#
# WORD #[ 294 / 500 ]
# 	Guess # 1 	: tunny 	Feedback:  [2, 1, 1, 2, 0]
# 	Guess # 2 	: bunts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: runts 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: cunts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  cunts 	Number of guesses:  4
#
#
# WORD #[ 295 / 500 ]
# 	Guess # 1 	: chili 	Feedback:  [0, 2, 2, 0, 2]
# 	Guess # 2 	: hives 	Feedback:  [2, 1, 0, 0, 0]
# 	Guess # 3 	: firth 	Feedback:  [1, 1, 0, 2, 2]
# 	Guess # 4 	: fight 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fight 	Number of guesses:  4
#
#
# WORD #[ 296 / 500 ]
# 	Guess # 1 	: corer 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: zooks 	Feedback:  [0, 1, 1, 0, 2]
# 	Guess # 3 	: boost 	Feedback:  [0, 1, 1, 1, 0]
# 	Guess # 4 	: goosy 	Feedback:  [0, 1, 1, 1, 0]
# 	Guess # 5 	: woosh 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  woosh 	Number of guesses:  5
#
#
# WORD #[ 297 / 500 ]
# 	Guess # 1 	: carte 	Feedback:  [0, 2, 2, 0, 1]
# 	Guess # 2 	: flare 	Feedback:  [0, 0, 1, 2, 1]
# 	Guess # 3 	: grave 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: brake 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: braze 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  braze 	Number of guesses:  5
#
#
# WORD #[ 298 / 500 ]
# 	Guess # 1 	: jibes 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 2 	: tipsy 	Feedback:  [0, 1, 0, 1, 1]
# 	Guess # 3 	: missy 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: sissy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sissy 	Number of guesses:  4
#
#
# WORD #[ 299 / 500 ]
# 	Guess # 1 	: watsa 	Feedback:  [0, 2, 0, 0, 1]
# 	Guess # 2 	: buffa 	Feedback:  [0, 0, 2, 2, 1]
# 	Guess # 3 	: fella 	Feedback:  [1, 2, 0, 0, 1]
# 	Guess # 4 	: fovea 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fovea 	Number of guesses:  4
#
#
# WORD #[ 300 / 500 ]
# 	Guess # 1 	: beamy 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 2 	: spars 	Feedback:  [2, 0, 1, 0, 1]
# 	Guess # 3 	: flaks 	Feedback:  [0, 2, 1, 0, 1]
# 	Guess # 4 	: coals 	Feedback:  [0, 0, 1, 1, 1]
# 	Guess # 5 	: quals 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  quals 	Number of guesses:  5
#
#
# WORD #[ 301 / 500 ]
# 	Guess # 1 	: pores 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: corky 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 3 	: forty 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 4 	: wormy 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: worry 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  worry 	Number of guesses:  5
#
#
# WORD #[ 302 / 500 ]
# 	Guess # 1 	: skier 	Feedback:  [2, 0, 2, 2, 2]
# 	Guess # 2 	: biers 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: liers 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: piers 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: viers 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  viers 	Number of guesses:  5
#
#
# WORD #[ 303 / 500 ]
# 	Guess # 1 	: hunks 	Feedback:  [2, 1, 1, 0, 0]
# 	Guess # 2 	: punch 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: munch 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  munch 	Number of guesses:  3
#
#
# WORD #[ 304 / 500 ]
# 	Guess # 1 	: eject 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: fluff 	Feedback:  [0, 2, 2, 0, 0]
# 	Guess # 3 	: gully 	Feedback:  [0, 1, 2, 1, 0]
# 	Guess # 4 	: burls 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: hurls 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  hurls 	Number of guesses:  5
#
#
# WORD #[ 305 / 500 ]
# 	Guess # 1 	: joust 	Feedback:  [0, 1, 0, 2, 0]
# 	Guess # 2 	: molls 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 3 	: bocks 	Feedback:  [2, 1, 0, 0, 1]
# 	Guess # 4 	: robes 	Feedback:  [0, 1, 1, 0, 1]
# 	Guess # 5 	: hobos 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  hobos 	Number of guesses:  5
#
#
# WORD #[ 306 / 500 ]
# 	Guess # 1 	: badly 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  badly 	Number of guesses:  1
#
#
# WORD #[ 307 / 500 ]
# 	Guess # 1 	: silts 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: chive 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 3 	: frizz 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 4 	: prior 	Feedback:  [0, 1, 1, 0, 2]
# 	Guess # 5 	: grimy 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  grimy 	Number of guesses:  5
#
#
# WORD #[ 308 / 500 ]
# 	Guess # 1 	: hunks 	Feedback:  [2, 0, 2, 0, 1]
# 	Guess # 2 	: johns 	Feedback:  [0, 0, 2, 1, 1]
# 	Guess # 3 	: whens 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: thens 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  thens 	Number of guesses:  4
#
#
# WORD #[ 309 / 500 ]
# 	Guess # 1 	: reman 	Feedback:  [2, 0, 0, 2, 1]
# 	Guess # 2 	: brawn 	Feedback:  [0, 2, 2, 0, 1]
# 	Guess # 3 	: caron 	Feedback:  [0, 2, 1, 1, 1]
# 	Guess # 4 	: apron 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  apron 	Number of guesses:  4
#
#
# WORD #[ 310 / 500 ]
# 	Guess # 1 	: obeah 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: pease 	Feedback:  [0, 2, 2, 2, 2]
# 	Guess # 3 	: safer 	Feedback:  [2, 1, 0, 1, 0]
# 	Guess # 4 	: gales 	Feedback:  [0, 1, 2, 1, 2]
# 	Guess # 5 	: easel 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  easel 	Number of guesses:  5
#
#
# WORD #[ 311 / 500 ]
# 	Guess # 1 	: doted 	Feedback:  [1, 0, 2, 0, 2]
# 	Guess # 2 	: durst 	Feedback:  [1, 1, 0, 2, 2]
# 	Guess # 3 	: dusty 	Feedback:  [1, 1, 2, 1, 0]
# 	Guess # 4 	: ducts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  ducts 	Number of guesses:  4
#
#
# WORD #[ 312 / 500 ]
# 	Guess # 1 	: cider 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 2 	: midst 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: didst 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  didst 	Number of guesses:  3
#
#
# WORD #[ 313 / 500 ]
# 	Guess # 1 	: duffs 	Feedback:  [2, 1, 2, 2, 0]
# 	Guess # 2 	: fumed 	Feedback:  [1, 1, 0, 1, 1]
# 	Guess # 3 	: fuzed 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  fuzed 	Number of guesses:  3
#
#
# WORD #[ 314 / 500 ]
# 	Guess # 1 	: larch 	Feedback:  [2, 2, 0, 0, 0]
# 	Guess # 2 	: float 	Feedback:  [1, 1, 0, 2, 0]
# 	Guess # 3 	: flask 	Feedback:  [1, 1, 1, 2, 0]
# 	Guess # 4 	: flams 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: flabs 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  flabs 	Number of guesses:  5
#
#
# WORD #[ 315 / 500 ]
# 	Guess # 1 	: grogs 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: letup 	Feedback:  [0, 0, 0, 2, 0]
# 	Guess # 3 	: fuzzy 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 4 	: mucky 	Feedback:  [0, 1, 0, 0, 1]
# 	Guess # 5 	: hubby 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  hubby 	Number of guesses:  5
#
#
# WORD #[ 316 / 500 ]
# 	Guess # 1 	: jello 	Feedback:  [0, 0, 2, 2, 0]
# 	Guess # 2 	: lupus 	Feedback:  [2, 0, 0, 0, 0]
# 	Guess # 3 	: flyby 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  flyby 	Number of guesses:  3
#
#
# WORD #[ 317 / 500 ]
# 	Guess # 1 	: gifts 	Feedback:  [0, 2, 0, 0, 0]
# 	Guess # 2 	: primo 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 3 	: krill 	Feedback:  [0, 1, 1, 0, 0]
# 	Guess # 4 	: crier 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 5 	: brier 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  brier 	Number of guesses:  5
#
#
# WORD #[ 318 / 500 ]
# 	Guess # 1 	: haven 	Feedback:  [0, 2, 1, 0, 2]
# 	Guess # 2 	: novas 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  novas 	Number of guesses:  2
#
#
# WORD #[ 319 / 500 ]
# 	Guess # 1 	: krill 	Feedback:  [0, 0, 1, 0, 0]
# 	Guess # 2 	: quipu 	Feedback:  [0, 0, 1, 2, 0]
# 	Guess # 3 	: spiff 	Feedback:  [2, 1, 1, 0, 0]
# 	Guess # 4 	: epics 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  epics 	Number of guesses:  4
#
#
# WORD #[ 320 / 500 ]
# 	Guess # 1 	: covet 	Feedback:  [0, 0, 0, 0, 2]
# 	Guess # 2 	: busty 	Feedback:  [0, 2, 2, 1, 0]
# 	Guess # 3 	: shuts 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 4 	: sluts 	Feedback:  [1, 0, 1, 1, 1]
# 	Guess # 5 	: smuts 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  smuts 	Number of guesses:  5
#
#
# WORD #[ 321 / 500 ]
# 	Guess # 1 	: lotto 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: shrub 	Feedback:  [0, 0, 2, 0, 0]
# 	Guess # 3 	: creek 	Feedback:  [1, 1, 1, 2, 0]
# 	Guess # 4 	: crepe 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 5 	: creme 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  creme 	Number of guesses:  5
#
#
# WORD #[ 322 / 500 ]
# 	Guess # 1 	: heals 	Feedback:  [1, 0, 2, 0, 1]
# 	Guess # 2 	: hafts 	Feedback:  [1, 1, 0, 0, 1]
# 	Guess # 3 	: harps 	Feedback:  [1, 1, 1, 0, 1]
# 	Guess # 4 	: harks 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  harks 	Number of guesses:  4
#
#
# WORD #[ 323 / 500 ]
# 	Guess # 1 	: phlox 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: crest 	Feedback:  [0, 2, 0, 2, 2]
# 	Guess # 3 	: turfs 	Feedback:  [2, 1, 2, 0, 2]
# 	Guess # 4 	: rusty 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  rusty 	Number of guesses:  4
#
#
# WORD #[ 324 / 500 ]
# 	Guess # 1 	: fives 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: milch 	Feedback:  [0, 1, 0, 0, 2]
# 	Guess # 3 	: bight 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: tight 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  tight 	Number of guesses:  4
#
#
# WORD #[ 325 / 500 ]
# 	Guess # 1 	: snaky 	Feedback:  [0, 1, 2, 0, 0]
# 	Guess # 2 	: unbar 	Feedback:  [1, 1, 1, 1, 0]
# 	Guess # 3 	: unban 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  unban 	Number of guesses:  3
#
#
# WORD #[ 326 / 500 ]
# 	Guess # 1 	: bland 	Feedback:  [0, 0, 2, 2, 2]
# 	Guess # 2 	: hands 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 3 	: rands 	Feedback:  [0, 1, 1, 1, 1]
# 	Guess # 4 	: sands 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  sands 	Number of guesses:  4
#
#
# WORD #[ 327 / 500 ]
# 	Guess # 1 	: flute 	Feedback:  [0, 0, 0, 1, 0]
# 	Guess # 2 	: cysts 	Feedback:  [0, 2, 0, 1, 0]
# 	Guess # 3 	: booty 	Feedback:  [0, 1, 2, 1, 1]
# 	Guess # 4 	: potty 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  potty 	Number of guesses:  4
#
#
# WORD #[ 328 / 500 ]
# 	Guess # 1 	: kilty 	Feedback:  [0, 1, 0, 0, 0]
# 	Guess # 2 	: gimps 	Feedback:  [1, 1, 2, 0, 2]
# 	Guess # 3 	: gismo 	Feedback:  [1, 1, 1, 1, 1]
#
# Success.	Correct word:  gismo 	Number of guesses:  3
#
#
# WORD #[ 329 / 500 ]
# 	Guess # 1 	: hoper 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 2 	: tusks 	Feedback:  [0, 0, 0, 0, 0]
# 	Guess # 3 	: flyby 	Feedback:  [0, 0, 0, 0, 0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 game = Game(Solver, N=500)
# ----> 2 game.run()
#
# Cell In[7], line 11, in Game.run(self)
#       9 solver = self.Solver()
#      10 print("WORD #[", i+1, "/", self.N, "]")
# ---> 11 solver.run()
#
# Cell In[6], line 35, in Wordle.run(self)
#      33 flag = False
#      34 for i in range(10):
# ---> 35     guessword = self.generate_guess(feedback)
#      36     feedback = self.feedback(guessword)
#      37     self.feedbacks.append(feedback)
#
# Cell In[8], line 71, in Solver.generate_guess(self, feedback)
#      67   wordIndex += 1
#      69 filterList(self.words)
# ---> 71 guess = random.choice(self.words)
#      72 self.words.remove(guess)
#      74 return guess
#
# File ~\anaconda3\Lib\random.py:373, in Random.choice(self, seq)
#     370 # As an accommodation for NumPy, we don't use "if not seq"
#     371 # because bool(numpy.array()) raises a ValueError.
#     372 if not len(seq):
# --> 373     raise IndexError('Cannot choose from an empty sequence')
#     374 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence
